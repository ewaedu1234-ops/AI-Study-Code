# %%
# USD -> KRW 환산
usd_amount = 500
krw_rate = 1350.5
print(f"500달러 = {usd_amount * krw_rate} 원")
# Out:
# 500달러 = 675250.0 원

# %%
# USD -> EUR 환산 (비슷한 식을 또 써야 함)
eur_rate = 0.92
print(f"500달러 = {usd_amount * eur_rate} 유로")
# Out:
# 500달러 = 460.0 유로
