# %%
import requests
API_KEY = "4ae57fd056a83f59e7561791b26b4d3a"

# 서울 날씨
url = f"https://api.openweathermap.org/data/2.5/weather?q=Seoul&appid={API_KEY}"
data = requests.get(url).json()
print(f"서울 날씨: {data['weather'][0]['main']}")
# Out:
# 서울 날씨: Clear

# %%
# 부산 날씨 (복사 붙여넣기 시작...)
url = f"https://api.openweathermap.org/data/2.5/weather?q=Busan&appid={API_KEY}"
data = requests.get(url).json()
print(f"부산 날씨: {data['weather'][0]['main']}")
# Out:
# 부산 날씨: Clear

# %%
# 제주 날씨 (또 복사 붙여넣기...)
url = f"https://api.openweathermap.org/data/2.5/weather?q=Jeju&appid={API_KEY}"
data = requests.get(url).json()
print(f"제주 날씨: {data['weather'][0]['main']}")
# Out:
# 제주 날씨: Clear
